# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# Upload the files

# %%
auction_df = pd.read_csv('auction_small.csv')
historical_prices_df = pd.read_csv('historical_prices.csv')
print("Files loaded successfully.")
print(f"First rows of auction_df:\n{auction_df.head()}")
print(f"First rows of historical_prices_df:\n{historical_prices_df.head()}")
# Out:
# Files loaded successfully.
# First rows of auction_df:
#    auction_id  bid_in_gold  buyout_in_gold  unit_price  quantity time_left  \
# 0   962303457      24.4708         27.1898     27.1898         1     SHORT
# 1   962303587      75.5135         83.9039     83.9039         1     SHORT
# 2   962303596     260.2195        289.1328    289.1328         1     SHORT
# 3   962303611      28.1145         31.2383     31.2383         1     SHORT
# 4   962303620     117.5188        130.5764    130.5764         1     SHORT
#
#    item_id              item_name   quality item_class  ...  \
# 0    13009        Cow King's Hide      Rare      Armor  ...
# 1    24684     Archmage Bracelets  Uncommon      Armor  ...
# 2    24695  Bonechewer Chestpiece  Uncommon      Armor  ...
# 3     7535          Cabalist Belt  Uncommon      Armor  ...
# 4    36069       Daggercap Jerkin  Uncommon      Armor  ...
#
#   purchase_price_gold  required_level  item_level  sell_price_gold  \
# 0                   7              46          51                1
# 1                   7              69         117                1
# 2                  13              57          81                2
# 3                   2              41          46                0
# 4                  21              67         130                4
#
#    first_appearance_timestamp  first_appearance_year first_appearance_month  \
# 0         2024-01-02 00:00:00                   2024                      1
# 1         2024-01-02 00:00:00                   2024                      1
# 2         2024-01-02 00:00:00                   2024                      1
# 3         2024-01-02 00:00:00                   2024                      1
# 4         2024-01-02 00:00:00                   2024                      1
#
#    first_appearance_day  first_appearance_hour  hours_on_sale
# 0                     2                      0              1
# 1                     2                      0              1
# 2                     2                      0              1
# 3                     2                      0              1
# 4                     2                      0              1
#
# [5 rows x 22 columns]
# First rows of historical_prices_df:
#               datetime  item_id    price
# 0  2024-02-13 23:00:00       35   2.4097
# 1  2024-02-13 23:00:00       40  75.0464
# 2  2024-02-13 23:00:00       43   9.5332
# 3  2024-02-13 23:00:00       51   3.0000
# 4  2024-02-13 23:00:00       53  22.9991

# %% [markdown]
# Convert date columns to datetime type

# %%
historical_prices_df['datetime'] = pd.to_datetime(historical_prices_df['datetime'])
auction_df['first_appearance_timestamp'] = pd.to_datetime(auction_df['first_appearance_timestamp'])
print("Datetime conversion completed.")
print(f"First rows of auction_df with converted datetime:\n{auction_df.head()}")
# Out:
# Datetime conversion completed.
# First rows of auction_df with converted datetime:
#    auction_id  bid_in_gold  buyout_in_gold  unit_price  quantity time_left  \
# 0   962303457      24.4708         27.1898     27.1898         1     SHORT
# 1   962303587      75.5135         83.9039     83.9039         1     SHORT
# 2   962303596     260.2195        289.1328    289.1328         1     SHORT
# 3   962303611      28.1145         31.2383     31.2383         1     SHORT
# 4   962303620     117.5188        130.5764    130.5764         1     SHORT
#
#    item_id              item_name   quality item_class  ...  \
# 0    13009        Cow King's Hide      Rare      Armor  ...
# 1    24684     Archmage Bracelets  Uncommon      Armor  ...
# 2    24695  Bonechewer Chestpiece  Uncommon      Armor  ...
# 3     7535          Cabalist Belt  Uncommon      Armor  ...
# 4    36069       Daggercap Jerkin  Uncommon      Armor  ...
#
#   purchase_price_gold  required_level  item_level  sell_price_gold  \
# 0                   7              46          51                1
# 1                   7              69         117                1
# 2                  13              57          81                2
# 3                   2              41          46                0
# 4                  21              67         130                4
#
#    first_appearance_timestamp  first_appearance_year first_appearance_month  \
# 0                  2024-01-02                   2024                      1
# 1                  2024-01-02                   2024                      1
# 2                  2024-01-02                   2024                      1
# 3                  2024-01-02                   2024                      1
# 4                  2024-01-02                   2024                      1
#
#    first_appearance_day  first_appearance_hour  hours_on_sale
# 0                     2                      0              1
# 1                     2                      0              1
# 2                     2                      0              1
# 3                     2                      0              1
# 4                     2                      0              1
#
# [5 rows x 22 columns]

# %% [markdown]
# Function to calculate the historical average price of the last 7 days

# %%
def calculate_historical_price(row):
    item_id = row['item_id']
    end_date = row['first_appearance_timestamp']
    start_date = end_date - timedelta(days=7)
    relevant_prices = historical_prices_df[(historical_prices_df['item_id'] == item_id) &
                                           (historical_prices_df['datetime'] >= start_date) &
                                           (historical_prices_df['datetime'] <= end_date)]
    
    if not relevant_prices.empty:
        print(f"Item ID: {item_id}")
        print(f"Date range: from {start_date} to {end_date}")
        print(f"Number of historical records found: {len(relevant_prices)}")
        print(f"Relevant prices:\n{relevant_prices['price'].values}")
        return relevant_prices['price'].mean()
    else:
        return np.nan

# %% [markdown]
# Apply the function to each row of auction_df

# %%
print("Calculating the average historical price for the last 7 days for each auction...")
auction_df['historical_price'] = auction_df.apply(calculate_historical_price, axis=1)
print("Calculation of the historical price completed.")
print(f"First rows of auction_df with historical_price:\n{auction_df[['item_id', 'historical_price']].head()}")
# Out:
# Calculando el precio histórico promedio de los últimos 7 días para cada subasta...
# Item ID: 13009
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [27.1895]
# Item ID: 24684
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [83.9039]
# Item ID: 24695
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [239.63945]
# Item ID: 7535
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [27.72205]
# Item ID: 36069
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [130.5764]
# Item ID: 6419
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [11.8797]
# Item ID: 10087
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [39.12325]
# Item ID: 15262
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [28.8543]
# Item ID: 7409
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [7.35458333]
# Item ID: 24822
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.]
# Item ID: 36150
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [31.40591537]
# Item ID: 24743
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [33.2473]
# Item ID: 36389
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [48.7749]
# Item ID: 36388
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [36.19185]
# Item ID: 25307
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [47.3138]
# Item ID: 36279
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [26.43965]
# Item ID: 36053
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [17.056]
# Item ID: 36053
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [17.056]
# Item ID: 36156
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [34.1033]
# Item ID: 36673
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [21.4718]
# Item ID: 33568
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.25452428]
# Item ID: 33567
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.27016252]
# Item ID: 33449
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.05204516]
# Item ID: 33449
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.05204516]
# Item ID: 33449
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.05204516]
# Item ID: 37705
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.54416142]
# Item ID: 37705
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.54416142]
# Item ID: 44750
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.03599024]
# Item ID: 44750
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.03599024]
# Item ID: 44750
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.03599024]
# Item ID: 12804
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.32730455]
# Item ID: 36907
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [3.02319019]
# Item ID: 43011
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.45514797]
# Item ID: 1705
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [8.00646737]
# Item ID: 1705
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [8.00646737]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 5213
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [2.3693834]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 10561
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.20139228]
# Item ID: 9867
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [9.9999]
# Item ID: 36921
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [19.40206288]
# Item ID: 3041
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [2.39670089]
# Item ID: 4384
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [2.81943209]
# Item ID: 36930
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [7.30646768]
# Item ID: 35580
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [41.587]
# Item ID: 14296
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.432]
# Item ID: 11972
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [12.1933]
# Item ID: 36072
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [40.9997]
# Item ID: 6398
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [7.58505]
# Item ID: 24592
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [30.2735]
# Item ID: 36181
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [57.4972]
# Item ID: 36185
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [14.1658]
# Item ID: 36175
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [74.7063]
# Item ID: 9822
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [6.999]
# Item ID: 36419
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [48.132435]
# Item ID: 14451
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [21.57475]
# Item ID: 24871
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [35.7033]
# Item ID: 36377
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [33.3121]
# Item ID: 36375
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [34.5907]
# Item ID: 35977
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [47.0934]
# Item ID: 15159
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [46.9052]
# Item ID: 7366
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [4.75]
# Item ID: 8400
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [0.8957]
# Item ID: 24591
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [28.8878]
# Item ID: 36088
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [20.]
# Item ID: 15263
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [35.18205]
# Item ID: 7447
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [7.83965]
# Item ID: 36432
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [211.5985]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 36200
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [58.4186]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 36012
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [84.2006]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 36269
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [57.39155]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 2579
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [1.45058367]
# Item ID: 36267
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [31.0228925]
# Item ID: 14678
# Rango de fechas: desde 2023-12-26 00:00:00 hasta 2024-01-02 00:00:00
# Número de registros históricos encontrados: 1
# Precios relevantes:
# [18.9979]
# Cálculo del precio histórico completado.
# Primeras filas de limited_auction_df con historical_price:
#    item_id  historical_price
# 0    13009          27.18950
# 1    24684          83.90390
# 2    24695         239.63945
# 3     7535          27.72205
# 4    36069         130.57640
# C:\Users\julio\AppData\Local\Temp\ipykernel_17544\2038777028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   limited_auction_df['historical_price'] = limited_auction_df.apply(calculate_historical_price, axis=1)

# %% [markdown]
# calculate the relative difference

# %%
print("Calculating the relative difference...")
auction_df['relative_historical_difference'] = (
    auction_df['unit_price'] - auction_df['historical_price']
) / auction_df['historical_price']
print("Calculation of the relative difference completed.")
print(f"First rows of auction_df with relative_historical_difference:\n{auction_df[['item_id', 'relative_historical_difference']].head()}")
# Out:
# Cálculo de la diferencia relativa...
# Cálculo de la diferencia relativa completado.
# Primeras filas de limited_auction_df con relative_historical_difference:
#    item_id  relative_historical_difference
# 0    13009                        0.000011
# 1    24684                        0.000000
# 2    24695                        0.206533
# 3     7535                        0.126839
# 4    36069                        0.000000
# C:\Users\julio\AppData\Local\Temp\ipykernel_17544\1272925851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   limited_auction_df['relative_historical_difference'] = (

# %% [markdown]
# Save the new DataFrame to an updated CSV file

# %%
output_path = r'C:\\Users\\julio\\Documents\\work\\auction_classic\\data\\historical\\auction_small_updated.csv'
auction_df.to_csv(output_path, index=False)
print(f"New columns added and file saved as '{output_path}'")
# Out:
# Nuevas columnas añadidas y archivo guardado como 'C:\\Users\\julio\\Documents\\work\\auction_classic\\data\\historical\\auction_small_limited_updated.csv'
